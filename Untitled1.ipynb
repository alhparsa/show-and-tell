# %%
import torch
from torchvision.models.detection import fasterrcnn_resnet50_fpn

# %%
model = fasterrcnn_resnet50_fpn(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /Users/alhparsa/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# ...

# %%
import requests
import PIL
import io

# %%
image = PIL.Image.open(io.BytesIO(requests.get('https://image.shutterstock.com/image-photo/two-dogs-playing-on-green-260nw-306529601.jpg').content))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=393x280 at 0x7FF8CF956670>

# %%
import torchvision.transforms as transforms

i = transforms.ToTensor()(image)

model.eval()
output = model(torch.unsqueeze(i,0))

# %%
output[0]['labels'].zero_()
# Out:
# tensor([0, 0])

# %%
from torchvision import models

# %%
pre_trained = models.resnet152(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /Users/alhparsa/.cache/torch/hub/checkpoints/resnet152-b121ed2d.pth
# ...

# %%
model
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-51-7468d5c26611> in <module>
# ----> 1 model.output
#
# /opt/miniconda3/envs/cmpt353/lib/python3.8/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     776             if name in modules:
#     777                 return modules[name]
# --> 778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
#     779             type(self).__name__, name))
#     780
#
# ModuleAttributeError: 'FasterRCNN' object has no attribute 'output'

# %%
i = torch.unsqueeze(i, 0)

# %%
pre_trained(i).shape
# Out:
# torch.Size([1, 1000])

# %%
s = torch.zeros(i.shape[0],91)

# %%
s[0][12] = 1

# %%
model(i).detach().cpu()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-572bbc9cad7e> in <module>
# ----> 1 model(i).detach().cpu()
#
# AttributeError: 'list' object has no attribute 'detach'

# %%
for p in model.parameters():
    print(p.requires_grad)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
